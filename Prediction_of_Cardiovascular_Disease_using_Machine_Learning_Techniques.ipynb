# %% [markdown]
# <h1 align="center"><b> Cardiovascular Disease Prediction using Machine Learning, Deep Learning, NLP, and Epoch-Based Training</b></h1>

# %% [markdown]
# # The objective of this project is to develop a comprehensive pipeline for predicting cardiovascular disease using patient health metrics. The study integrates multiple Machine Learning models, a Deep Learning neural network, and Natural Language Processing (NLP) techniques for feature analysis. Additionally, model training is monitored through epoch-based performance tracking, and the final system is deployed as an interactive Streamlit application for real-time prediction and decision support.
# </p>

# %% [markdown]
# # 1. Import  Libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.default = 'colab'
from scipy.stats import ttest_ind, chi2_contingency
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix
import xgboost as xgb
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, Callback
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import time
import warnings
warnings.filterwarnings('ignore')
import joblib
print(" All libraries imported.")

# %% [markdown]
# # 2. Load the Dataset

# %%
df = pd.read_csv("/content/NACC_APOE_CVD_filtered (2).csv")

# %%
df.head()
# Out:
#        NACCID  SEX  BIRTHYR  NACCAPOE  DEMENTED  CVHATT  HATTMULT  CVAFIB  \
# 0  NACC000011    2     1944       1.0         0     0.0       NaN     0.0
# 1  NACC000034    2     1935       4.0         0     0.0       8.0     0.0
# 2  NACC000067    1     1952       1.0         0     0.0       NaN     0.0
# 3  NACC000095    1     1926       2.0         1     0.0       NaN     0.0
# 4  NACC000144    1     1930       1.0         0     0.0       NaN     1.0
#
#    CVANGIO  CVBYPASS  ...  STROKE  STROKIF  STROKDEC  STKIMAG  CVD  CVDIF  \
# 0      0.0       0.0  ...     0.0      7.0       NaN      NaN  NaN    NaN
# 1      0.0       0.0  ...     NaN      NaN       8.0      8.0  0.0    7.0
# 2      0.0       0.0  ...     0.0      7.0       NaN      NaN  NaN    NaN
# 3      0.0       0.0  ...     0.0      7.0       NaN      NaN  NaN    NaN
# 4      0.0       0.0  ...     0.0      8.0       NaN      NaN  NaN    NaN
#
#   VASC  VASCIF  VASCPS  VASCPSIF
# 0  0.0     7.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40686 entries, 0 to 40685
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NACCID    40686 non-null  object
#  1   SEX       40686 non-null  int64
#  2   BIRTHYR   40686 non-null  int64
#  3   NACCAPOE  40686 non-null  float64
#  4   DEMENTED  40686 non-null  int64
#  5   CVHATT    29582 non-null  float64
#  6   HATTMULT  7713 non-null   float64
#  7   CVAFIB    29536 non-null  float64
#  8   CVANGIO   29624 non-null  float64
#  9   CVBYPASS  29633 non-null  float64
#  10  CVPACDEF  7742 non-null   float64
#  11  CVPACE    21901 non-null  float64
#  12  CVCHF     29598 non-null  float64
#  13  CVANGINA  7738 non-null   float64
#  14  CVHVALVE  7738 non-null   float64
#  15  CVOTHR    29536 non-null  float64
#  16  CVOTHRX   3347 non-null   object
#  17  MYOINF    18764 non-null  float64
#  18  CONGHRT   18764 non-null  float64
# ...

# %% [markdown]
# # 3. Data Cleaning & Preprocessing

# %%
# Remove id column
df.drop('id', axis=1, inplace=True)

# Convert age from days to years (real dataset has age in days)
if df['age'].max() > 100:
    df['age'] = (df['age'] / 365.25).astype(int)

# Remove outliers in blood pressure (ap_hi, ap_lo)
df = df[(df['ap_hi'] > 50) & (df['ap_hi'] < 250)]
df = df[(df['ap_lo'] > 30) & (df['ap_lo'] < 200)]

# Create BMI
df['bmi'] = df['weight'] / ((df['height']/100) ** 2)
df['bmi'] = df['bmi'].clip(10, 50)

# Create age groups
df['age_group'] = pd.cut(df['age'], bins=[20,40,50,60,70], labels=['20-40','40-50','50-60','60-70'])

print(f"After cleaning: {df.shape}")
df.head()

# %% [markdown]
# # 4. Exploratory Data Analysis (EDA)

# %% [markdown]
# # 4.1 Target Distribution

# %%
fig = px.pie(df, names='cardio', title='Cardiovascular Disease Distribution (1=Disease)',
             color_discrete_sequence=['lightgreen','coral'])
fig.show()

# %% [markdown]
# # 4.2 Age Distribution by Target

# %%
fig = px.histogram(df, x='age', color='cardio', barmode='overlay', opacity=0.6,
                   title='Age Distribution by CVD Status')
fig.show()

# %% [markdown]
# # 4.3 Blood Pressure Analysis

# %%
fig = make_subplots(rows=1, cols=2, subplot_titles=('Systolic BP', 'Diastolic BP'))
fig.add_trace(go.Box(x=df['cardio'], y=df['ap_hi'], name='Systolic'), row=1, col=1)
fig.add_trace(go.Box(x=df['cardio'], y=df['ap_lo'], name='Diastolic'), row=1, col=2)
fig.update_layout(title='Blood Pressure by CVD Status')
fig.show()

# %% [markdown]
# # 4.4 Cholesterol & Glucose Levels

# %%
fig = make_subplots(rows=1, cols=2, subplot_titles=('Cholesterol', 'Glucose'))
for val in [1,2,3]:
    subset = df[df['cholesterol']==val]
    fig.add_trace(go.Bar(x=['1','2','3'], y=[subset['cardio'].mean()], name=f'Chol {val}'), row=1, col=1)
    subset2 = df[df['gluc']==val]
    fig.add_trace(go.Bar(x=['1','2','3'], y=[subset2['cardio'].mean()], name=f'Gluc {val}'), row=1, col=2)
fig.update_layout(title='CVD Prevalence by Cholesterol and Glucose Levels', showlegend=False)
fig.show()

# %% [markdown]
# # 4.5 Lifestyle Factors

# %%
lifestyle = ['smoke', 'alco', 'active']
fig = make_subplots(rows=1, cols=3, subplot_titles=lifestyle)
for i, col in enumerate(lifestyle):
    grouped = df.groupby(col)['cardio'].mean().reset_index()
    fig.add_trace(go.Bar(x=grouped[col], y=grouped['cardio'], name=col), row=1, col=i+1)
fig.update_layout(title='CVD Prevalence by Lifestyle Factors')
fig.show()

# %% [markdown]
# # 4.6 Correlation Heatmap

# %%
numeric_cols = ['age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'bmi', 'cardio']
corr = df[numeric_cols].corr()
fig = px.imshow(corr, text_auto=True, title='Correlation Heatmap', color_continuous_scale='RdBu', zmin=-1, zmax=1)
fig.show()

# %% [markdown]
# # 5. Statistical Tests

# %%
# T-test for continuous features
cont_features = ['age', 'ap_hi', 'ap_lo', 'bmi']
ttest_results = []
for col in cont_features:
    group1 = df[df['cardio']==1][col]
    group0 = df[df['cardio']==0][col]
    t_stat, p = ttest_ind(group1, group0, equal_var=False)
    ttest_results.append({'Feature': col, 'P-value': p})
pd.DataFrame(ttest_results).sort_values('P-value')

# %%
# Chi-square for categorical
cat_features = ['gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active']
chi2_results = []
for col in cat_features:
    ct = pd.crosstab(df[col], df['cardio'])
    chi2, p, _, _ = chi2_contingency(ct)
    chi2_results.append({'Feature': col, 'P-value': p})
pd.DataFrame(chi2_results).sort_values('P-value')

# %% [markdown]
# # 6. Feature Engineering & Preprocessing

# %%
# One-hot encode age groups
age_dummies = pd.get_dummies(df['age_group'], prefix='age')
df = pd.concat([df, age_dummies], axis=1)

# Select features for modeling
feature_cols = ['age', 'gender', 'ap_hi', 'ap_lo', 'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'bmi'] + list(age_dummies.columns)
X = df[feature_cols]
y = df['cardio']

# Scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
print(f"Train: {X_train.shape[0]}, Test: {X_test.shape[0]}")

# %% [markdown]
# # 7. Machine Learning Models

# %%
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(n_estimators=100),
    'Gradient Boosting': GradientBoostingClassifier(),
    'SVM': SVC(probability=True),
    'XGBoost': xgb.XGBClassifier(eval_metric='logloss')
}

results = {}
predictions = {}
probas = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:,1]
    predictions[name] = y_pred
    probas[name] = y_proba
    acc = accuracy_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_proba)
    results[name] = {'Accuracy': acc, 'AUC': auc}
    print(f"{name:20} | Accuracy: {acc:.4f} | AUC: {auc:.4f}")

# %%
# Comparison plot
res_df = pd.DataFrame(results).T.reset_index().rename(columns={'index': 'Model'})
fig = px.bar(res_df, x='Model', y=['Accuracy', 'AUC'], barmode='group', title='Model Performance')
fig.show()

# %% [markdown]
# # 8. Deep Learning with Epoch Tracking

# %%
class EpochLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        if (epoch+1) % 10 == 0:
            print(f"Epoch {epoch+1}: loss={logs['loss']:.4f}, acc={logs['accuracy']:.4f}, val_loss={logs['val_loss']:.4f}, val_acc={logs['val_accuracy']:.4f}")

# %%
nn_model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
nn_model.compile(optimizer=Adam(0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = nn_model.fit(X_train, y_train, epochs=100, batch_size=128, validation_split=0.2,
                       callbacks=[early_stop, EpochLogger()], verbose=0)

# %%
# Plot training history
fig = make_subplots(rows=1, cols=2, subplot_titles=('Loss', 'Accuracy'))
fig.add_trace(go.Scatter(y=history.history['loss'], name='Train Loss'), row=1, col=1)
fig.add_trace(go.Scatter(y=history.history['val_loss'], name='Val Loss'), row=1, col=1)
fig.add_trace(go.Scatter(y=history.history['accuracy'], name='Train Acc'), row=1, col=2)
fig.add_trace(go.Scatter(y=history.history['val_accuracy'], name='Val Acc'), row=1, col=2)
fig.update_layout(title='Neural Network Training History')
fig.show()

# %%
nn_proba = nn_model.predict(X_test).flatten()
nn_acc = accuracy_score(y_test, (nn_proba >= 0.5).astype(int))
nn_auc = roc_auc_score(y_test, nn_proba)
print(f"Neural Network -> Accuracy: {nn_acc:.4f}, AUC: {nn_auc:.4f}")

# %% [markdown]
# # 9. NLP on Feature Names

# %%
feature_text = ' '.join(feature_cols)
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform([feature_text])
tfidf_scores = tfidf_matrix.toarray()[0]
terms = vectorizer.get_feature_names_out()
tfidf_df = pd.DataFrame({'Term': terms, 'Score': tfidf_scores}).sort_values('Score', ascending=False).head(10)
fig = px.bar(tfidf_df, x='Score', y='Term', orientation='h', title='TF-IDF of Feature Terms')
fig.show()

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(feature_text)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Feature Names Word Cloud')
plt.axis('off')
plt.show()

# %% [markdown]
# # 10. Save Best Model

# %%
best_model_name = max(results, key=lambda x: results[x]['AUC'])
best_model = models[best_model_name]
joblib.dump(best_model, 'cvd_best_model.pkl')
joblib.dump(scaler, 'cvd_scaler.pkl')
joblib.dump(feature_cols, 'cvd_features.pkl')
print(f" Best model ({best_model_name}) saved.")

# %% [markdown]
# # 11. Streamlit App

# %%
# !pip install streamlit pyngrok -q

# Write the Streamlit app code to a file
# %%writefile app.py
import streamlit as st
import pandas as pd
import numpy as np
import joblib

# Load model and preprocessors
model = joblib.load('cvd_best_model.pkl')
scaler = joblib.load('cvd_scaler.pkl')
features = joblib.load('cvd_features.pkl')

st.set_page_config(page_title="CVD Predictor", layout="centered")
st.title("🫀 Cardiovascular Disease Risk Predictor")
st.markdown("Enter patient health metrics to predict CVD risk.")

col1, col2 = st.columns(2)
with col1:
    age = st.number_input("Age (years)", 20, 80, 50)
    gender = st.selectbox("Gender", ["Female", "Male"])
    ap_hi = st.number_input("Systolic BP (mm Hg)", 80, 250, 120)
    ap_lo = st.number_input("Diastolic BP (mm Hg)", 50, 200, 80)
    cholesterol = st.selectbox("Cholesterol", ["Normal", "Above Normal", "Well Above Normal"])
with col2:
    gluc = st.selectbox("Glucose", ["Normal", "Above Normal", "Well Above Normal"])
    smoke = st.selectbox("Smoking", ["No", "Yes"])
    alco = st.selectbox("Alcohol intake", ["No", "Yes"])
    active = st.selectbox("Physical activity", ["No", "Yes"])
    weight = st.number_input("Weight (kg)", 30, 150, 70)
    height = st.number_input("Height (cm)", 100, 200, 170)

# Convert inputs
gender_val = 1 if gender == "Male" else 2
chol_val = {"Normal":1, "Above Normal":2, "Well Above Normal":3}[cholesterol]
gluc_val = {"Normal":1, "Above Normal":2, "Well Above Normal":3}[gluc]
smoke_val = 1 if smoke == "Yes" else 0
alco_val = 1 if alco == "Yes" else 0
active_val = 1 if active == "Yes" else 0
bmi = weight / ((height/100)**2)

# Age groups
age_groups = [f'age_{g}' for g in ['20-40','40-50','50-60','60-70']]
age_group = '20-40' if age < 40 else ('40-50' if age < 50 else ('50-60' if age < 60 else '60-70'))

# Create feature vector
input_dict = {
    'age': age, 'gender': gender_val, 'ap_hi': ap_hi, 'ap_lo': ap_lo,
    'cholesterol': chol_val, 'gluc': gluc_val, 'smoke': smoke_val,
    'alco': alco_val, 'active': active_val, 'bmi': bmi,
    'age_20-40': 1 if age_group=='20-40' else 0,
    'age_40-50': 1 if age_group=='40-50' else 0,
    'age_50-60': 1 if age_group=='50-60' else 0,
    'age_60-70': 1 if age_group=='60-70' else 0
}
input_df = pd.DataFrame([input_dict])[features]
input_scaled = scaler.transform(input_df)
prob = model.predict_proba(input_scaled)[0][1]

st.markdown("---")
if st.button("Predict CVD Risk"):
    st.subheader("Prediction Result")
    if prob >= 0.5:
        st.error(f" High risk of cardiovascular disease (Probability: {prob:.2%})")
        st.markdown(" **Recommendation:** Consult a cardiologist immediately.")
    else:
        st.success(f" Low risk of cardiovascular disease (Probability: {(1-prob):.2%})")
        st.markdown(" **Recommendation:** Maintain healthy lifestyle and regular checkups.")

# %%
from pyngrok import ngrok
import time
import subprocess
import os

# Kill any existing Streamlit processes
# !pkill streamlit 2>/dev/null
time.sleep(1)

# Set up ngrok authtoken (optional but recommended)
# ngrok.set_auth_token("YOUR_TOKEN")  # uncomment if you have an account

# Run Streamlit in background
log_file = open("streamlit_log.txt", "w")
process = subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501", "--server.headless", "true"],
                           stdout=log_file, stderr=log_file)

# Wait for startup
time.sleep(5)

# Create public URL
public_url = ngrok.connect(8501, "http")
print(f"\n Streamlit app is running!\n Click here to open: {public_url}")
print("Keep this cell running. To stop, interrupt the kernel.")

# %% [markdown]
# # 12. Final Evaluation & Summary

# %%
# Combine all results
results['Neural Network'] = {'Accuracy': nn_acc, 'AUC': nn_auc}
final_df = pd.DataFrame(results).T.sort_values('AUC', ascending=False)
final_df

# %% [markdown]
# # Project Completed

# %% [markdown]
# # Dataset
# # We use the Cardiovascular Disease Dataset from Kaggle (70,000+ patients, 13 features).
# # Download link: https://www.kaggle.com/datasets/sulianova/cardiovascular-disease-dataset
