# %% [markdown]
# # **🔍 OCR (Optical Character Recognition) – Text Extraction System**

# %% [markdown]
# # **Optical Character Recognition (OCR)** is a technology used to convert images, scanned documents, and PDFs into editable and searchable text. It enables efficient data extraction from printed or digital documents, reducing manual effort and improving accuracy. OCR systems are widely used in document processing, automation, and data analysis applications.

# %%
https://usamaocrfinalwesite.netlify.app/

# %% [markdown]
# # https://usamaocrfinalwesite.netlify.app/
