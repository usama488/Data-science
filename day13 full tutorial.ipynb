# %% [markdown]
# # Automated  EDA using ydata _profiling

# %% [markdown]
# # install ydata_profiling library

# %%
# !pip install ydata-profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.7/398.7 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 47.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import seaborn as sns
import ydata_profiling as yd

# %% [markdown]
# # import data from seaborn

# %%
df=sns.load_dataset('titanic')

# %% [markdown]
# # ydata profile report

# %%
profile = yd.ProfileReport(df)
profile.to_file(output_file='ydata_titanic.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from google.colab import files

files.download('ydata_titanic.html')

# %% [markdown]
# # now do it on our pak population dataset

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import seaborn as sns
import ydata_profiling as yd

# %% [markdown]
# ##                                                        import the data

# %% [markdown]
# ### Upload your dataset
#
# To import a file from your local computer (desktop) into Colab, you can use `google.colab.files.upload()`.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  # Assuming you want to read the first uploaded file
  uploaded_filename = fn

# %%
profile_pop = yd.ProfileReport(df_pop)
profile_pop.to_file(output_file='ydata_population.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-712128065.py in <cell line: 0>()
# ----> 1 profile_pop = yd.ProfileReport(df_pop)
#       2 profile_pop.to_file(output_file='ydata_population.html')
#
# NameError: name 'yd' is not defined

# %%
from google.colab import files
files.download('ydata_population.html')

# %% [markdown]
# # pak vs india ball by ball dataset

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import seaborn as sns
import ydata_profiling as yd

# %% [markdown]
# ##                                                        import the data

# %% [markdown]
# ### Upload your dataset
#
# To import a file from your local computer (desktop) into Colab, you can use `google.colab.files.upload()`.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  # Assuming you want to read the first uploaded file
  uploaded_filename = fn

# %%
df_pak_vs_india = pd.read_csv(uploaded_filename)
profile_pak_vs_india = yd.ProfileReport(df_pak_vs_india)
profile_pak_vs_india.to_file(output_file='ydata_pak_vs_india.html')

# %%
from google.colab import files
files.download('ydata_pak_vs_india.html')

# %% [markdown]
# # how to do skiming of the data

# %% [markdown]
# # import libraries

# %%
# !pip install skimpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.0/118.0 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 122.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 86.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 7.4.9
#     Uninstalling jupyter_client-7.4.9:
#       Successfully uninstalled jupyter_client-7.4.9
#   Attempting uninstall: ipykernel
# ...

# %% [markdown]
# # import libraries

# %%
import pandas as pd
import seaborn as sns
from skimpy import skim

# %%
import seaborn as sns
df = sns.load_dataset('titanic')
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types               Categories                                        │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓ ┏━━━━━━━━━━━━━━━━━━━━━━━┓                                │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃ ┃ Categorical Variables ┃                                │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩ ┡━━━━━━━━━━━━━━━━━━━━━━━┩                                │
# │ │ Number of rows    │ 891    │ │ string      │ 5     │ │ class                 │                                │
# │ │ Number of columns │ 15     │ │ int64       │ 4     │ │ deck                  │                                │
# │ └───────────────────┴────────┘ │ float64     │ 2     │ └───────────────────────┘                                │
# ...
